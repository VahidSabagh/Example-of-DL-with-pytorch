# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Linear Regression

# %%
x=np.random.rand(100,1)
y=1+2*x + (0.1 * np.random.randn(100,1))  #noise: np.random.randn(100,1)

# %% [markdown]
# ## Separate training and test data
# ###### From Shuffle to randomly select samples

# %%
idx = np.arange(100)
np.random.shuffle(idx)
# Out:
# array([55, 54, 31, 36, 85, 62,  3, 45, 42, 86, 14, 32, 97, 82, 92, 43, 13,
#        28, 35, 46, 70, 72, 65,  6, 49, 76, 22, 71, 47, 16, 20, 91, 68, 78,
#        87, 64, 63, 26, 18, 19, 39, 75, 40,  0, 80, 15, 10, 98, 67, 41, 77,
#        27, 96, 44,  4,  5, 81, 29, 84, 51, 66, 38, 83, 56, 50, 48, 12, 73,
#         1, 94, 61, 79, 21, 52,  2, 33, 89, 60, 99, 24,  8, 59, 74, 17,  9,
#        90, 53, 88, 58, 25, 69,  7, 95, 37, 34, 93, 11, 57, 30, 23])

# %%
train_idx = idx[:80]
test_idx = idx[80:]

x_train, y_train = x[train_idx],y[train_idx]
x_test, y_test = x[test_idx],y[test_idx]

# %%
plt.plot(x_train,y_train,'o')

# %%
plt.plot(x_test,y_test,'o')

# %% [markdown]
# # Model

# %%
a = np.random.randn(1)
b = np.random.randn(1)
print('a,b:  ', a, b)
yp = a + b * x_train
# Out:
# a,b:   [-0.62112211] [0.23516422]

# %% [markdown]
# # Loss

# %%
error = (y_train - yp)
loss = (error ** 2).mean()
loss #MSE
# Out:
# 0.016907099193996987

# %% [markdown]
# # Gradient calculations

# %%
a_grad = -2 * error.mean()
b_grad = -2 * (x_train * error).mean()
print(a_grad, b_grad)
# Out:
# 7.517790088581234 4.371544578457888

# %% [markdown]
# # update

# %%
lr = 0.01        #learning rate

# %%
a = a - lr * a_grad
b = b - lr * b_grad

print('a,b:  ', a, b)
# Out:
# a,b:   [-0.41022024] [-0.25278177]

# %% [markdown]
# # Main

# %%
np.random.seed(2)
a = np.random.randn(1)
b = np.random.randn(1)
lr = 0.1
n_epochs = 100
print('a,b:  ', a, b)

for epoch in range(n_epochs):
    # model
    yp = a + b * x_train

    # loss
    error = (y_train - yp)
    loss = (error ** 2).mean()

    # gradiant
    a_grad = -2 * error.mean()
    b_grad = -2 * (x_train * error).mean()

    # update
    a = a - lr * a_grad
    b = b - lr * b_grad
    
    print(loss)
print('a,b  --->  ', a, b)
# Out:
# a,b:   [-0.41675785] [-0.05626683]
# 6.657459609053893
# 3.699407855033981
# 2.0742283522550258
# 1.1808677323692531
# 0.6893288370023483
# 0.418432480082419
# 0.26870500790259033
# 0.1855315667086895
# 0.1389261466451695
# 0.11242473166461667
# 0.09698730679771878
# 0.08764987756116592
# 0.08168632808846857
# 0.07759922578067077
# 0.07456574234416553
# 0.07213344731985441
# 0.07005328908141402
# 0.06818789586328082
# 0.06646122974798693
# 0.06483094467742646
# 0.063273209665712
# 0.06177437579426968
# 0.060326400661824355
# 0.05892433580307652
# 0.057564946752198275
# 0.05624595497520061
# 0.05496562123956319
# 0.05372251645544092
# 0.05251539545633875
# 0.05134312730826015
# 0.05020465666597342
# 0.04909898218604714
# 0.0480251443152191
# 0.04698221823645556
# 0.04596930965679021
# 0.0449855521651502
# 0.044030105461635584
# 0.04310215407446377
# 0.04220090635360263
# 0.04132559362500234
# 0.04047546944143913
# 0.039649808894597696
# 0.038847907968735204
# 0.03806908292490543
# 0.03731266970946982
# 0.03657802338323498
# 0.03586451756899696
# 0.035171543916070115
# 0.03449851158082163
# 0.03384484672248201
# 0.03320999201364411
# 0.032593406164947165
# 0.031994563463492894
# 0.03141295332457396
# 0.030848079856318704
# 0.030299461436872586
# 0.029766630303751908
# 0.029249132155017114
# 0.028746525761924456
# 0.028258382592724795
# 0.027784286447288954
# 0.027323833102247064
# 0.026876629966339972
# 0.026442295745688356
# 0.02602046011869431
# 0.025610763420298045
# 0.025212856335320666
# 0.024826399600631394
# 0.02445106371588537
# 0.0240865286625854
# 0.023732483631228114
# 0.023388626756301944
# 0.0230546648589108
# 0.022730313196804144
# 0.022415295221600424
# 0.02210934234299667
# 0.021812193699763224
# 0.021523595937328627
# 0.02124330299176458
# 0.02097107587998725
# 0.02070668249599575
# 0.020449897412974122
# 0.020200501691088203
# 0.019958282690813314
# 0.019723033891633834
# 0.01949455471595983
# 0.01927265035811081
# 0.01905713161822074
# 0.018847814740922612
# 0.018644521258675117
# 0.018447077839597904
# 0.018255316139685458
# 0.018069072659273832
# 0.017888188603637733
# 0.017712509747599116
# 0.01754188630403189
# 0.017376172796150585
# 0.017215227933474
# 0.017058914491358386
# 0.016907099193996987
# a,b  --->   [1.11679695] [1.80343709]

# %%
plt.plot(x_test, y_test, "ro")

yhat = a + b * x_test

plt.plot(x_test, yhat, 'g')

# %% [markdown]
# # torch1

# %%
import torch

# %%
# np.random.seed(2)
# a = np.random.randn(1)
# b = np.random.randn(1)
y_train = torch.from(y_train)
x_train = torch.from(x_train)    #Numpy array is converted to tensor


torch.manual_seed(10)
a = torch.randn(1)
b = torch.randn(1)


lr = 0.1
n_epochs = 100
print('a,b:  ', a, b)

for epoch in range(n_epochs):
    # model
    yp = a + b * x_train

    # loss
    error = (y_train - yp)
    loss = (error ** 2).mean()

    # gradiant
    a_grad = -2 * error.mean()
    b_grad = -2 * (x_train * error).mean()

    # update
    a = a - lr * a_grad
    b = b - lr * b_grad
    
    print(loss)
print('a,b  --->  ', a, b)
